# %%
import re
import numpy as np

with open('fitnessA_01.txt') as f:
    linesA = f.readlines()
with open('fitnessA_02.txt') as f:
    lines2A = f.readlines()  
with open('fitnessA_03.txt') as f:
    lines3A = f.readlines()  
with open('fitnessA_04.txt') as f:
    lines4A = f.readlines()  
with open('fitnessA_05.txt') as f:
    lines5A = f.readlines()  
    
for i in range(len(linesA)):
    linesA[i] = linesA[i].split(",",1)[0]
linesA = np.array(linesA)
linesA = linesA.astype(np.float)

for i in range(len(lines2A)):
    lines2A[i] = lines2A[i].split(",",1)[0]
lines2A = np.array(lines2A)
lines2A = lines2A.astype(np.float)

for i in range(len(lines3A)):
    lines3A[i] = lines3A[i].split(",",1)[0]
lines3A = np.array(lines3A)
lines3A = lines3A.astype(np.float)

for i in range(len(lines4A)):
    lines4A[i] = lines4A[i].split(",",1)[0]
lines4A = np.array(lines4A)
lines4A = lines4A.astype(np.float)

for i in range(len(lines5A)):
    lines5A[i] = lines5A[i].split(",",1)[0]
lines5A = np.array(lines5A)
lines5A = lines5A.astype(np.float)

# %%
with open('fitnessB_01.txt') as f:
    linesB = f.readlines()
with open('fitnessB_02.txt') as f:
    lines2B = f.readlines()  
with open('fitnessB_03.txt') as f:
    lines3B = f.readlines()  
with open('fitnessB_04.txt') as f:
    lines4B = f.readlines()  
with open('fitnessB_05.txt') as f:
    lines5B = f.readlines()  
    
for i in range(len(linesB)):
    linesB[i] = linesB[i].split(",",1)[0]
linesB = np.array(linesB)
linesB = linesB.astype(np.float)

for i in range(len(lines2B)):
    lines2B[i] = lines2B[i].split(",",1)[0]
lines2B = np.array(lines2B)
lines2B = lines2B.astype(np.float)

for i in range(len(lines3B)):
    lines3B[i] = lines3B[i].split(",",1)[0]
lines3B = np.array(lines3B)
lines3B = lines3B.astype(np.float)

for i in range(len(lines4B)):
    lines4B[i] = lines4B[i].split(",",1)[0]
lines4B = np.array(lines4B)
lines4B = lines4B.astype(np.float)

for i in range(len(lines5B)):
    lines5B[i] = lines5B[i].split(",",1)[0]
lines5B = np.array(lines5B)
lines5B = lines5B.astype(np.float)
